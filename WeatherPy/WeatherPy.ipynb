# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

from config import api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)

output_data_file = "Cities.csv"

# Range of latitudes and longitudes

lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Create empty lists to append the API data into lists 

city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the counter 

counter = 1
Set = 1

# Start file statement

print("Beginning Data Retrieval")
print("-------------------------------")

#Loopinp through the cities in the cities 

for city in cities:  
    
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_counter = response["name"]
        print(f"Processing Record {counter} of set {Set} | {city_counter}")

        # Increase counter by one 
        
        counter += 1
        
    # Message to show in case no records is found
    
    except:
        Set +=1 
        print("City" +"\033[1m{}\033[0m".format(' not')+ " found. Skipping...")
        continue

# End file statement

print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of set 1 | Ushuaia
# Processing Record 2 of set 1 | Carauari
# Processing Record 3 of set 1 | Cidreira
# Processing Record 4 of set 1 | Haines Junction
# Processing Record 5 of set 1 | Georgetown
# Processing Record 6 of set 1 | San Ignacio
# Processing Record 7 of set 1 | Caiaponia
# Processing Record 8 of set 1 | Taloda
# Processing Record 9 of set 1 | Asuncion
# Processing Record 10 of set 1 | Khatanga
# Processing Record 11 of set 1 | Nikolskoye
# Processing Record 12 of set 1 | Busselton
# Processing Record 13 of set 1 | Bluff
# Processing Record 14 of set 1 | Hermanus
# Processing Record 15 of set 1 | Mar del Plata
# City not found. Skipping...
# Processing Record 16 of set 2 | Sao Filipe
# Processing Record 17 of set 2 | Saint Peter
# Processing Record 18 of set 2 | Avarua
# Processing Record 19 of set 2 | Onokhoy
# Processing Record 20 of set 2 | Chokurdakh
# Processing Record 21 of set 2 | Punta Arenas
# Processing Record 22 of set 2 | Cape Town
# Processing Record 23 of set 2 | Komsomolskiy
# Processing Record 24 of set 2 | Hithadhoo
# City not found. Skipping...
# Processing Record 25 of set 3 | New Norfolk
# Processing Record 26 of set 3 | Atuona
# Processing Record 27 of set 3 | Bethel
# Processing Record 28 of set 3 | Grindavik
# Processing Record 29 of set 3 | Victoria
# Processing Record 30 of set 3 | Broome
# City not found. Skipping...
# Processing Record 31 of set 4 | Lavrentiya
# Processing Record 32 of set 4 | Nanortalik
# Processing Record 33 of set 4 | Rikitea
# Processing Record 34 of set 4 | Half Moon Bay
# City not found. Skipping...
# Processing Record 35 of set 5 | Hong Gai
# Processing Record 36 of set 5 | Hobart
# Processing Record 37 of set 5 | Clyde River
# Processing Record 38 of set 5 | Carnot
# Processing Record 39 of set 5 | Porto Murtinho
# Processing Record 40 of set 5 | Road Town
# Processing Record 41 of set 5 | Saskylakh
# Processing Record 42 of set 5 | Mnogovershinnyy
# Processing Record 43 of set 5 | Magadan
# Processing Record 44 of set 5 | Anuchino
# City not found. Skipping...
# Processing Record 45 of set 6 | Qaanaaq
# Processing Record 46 of set 6 | Kaitangata
# Processing Record 47 of set 6 | Vaini
# Processing Record 48 of set 6 | Cayenne
# Processing Record 49 of set 6 | Choya
# Processing Record 50 of set 6 | Avera
# City not found. Skipping...
# Processing Record 51 of set 7 | Galesong
# Processing Record 52 of set 7 | Iqaluit
# City not found. Skipping...
# Processing Record 53 of set 8 | Ancud
# Processing Record 54 of set 8 | Bredasdorp
# Processing Record 55 of set 8 | Souillac
# Processing Record 56 of set 8 | Castro
# Processing Record 57 of set 8 | Vao
# Processing Record 58 of set 8 | Ivanteyevka
# Processing Record 59 of set 8 | Sinnamary
# Processing Record 60 of set 8 | Abu Samrah
# Processing Record 61 of set 8 | Mataura
# Processing Record 62 of set 8 | Carnarvon
# Processing Record 63 of set 8 | Kodiak
# City not found. Skipping...
# Processing Record 64 of set 9 | Adrar
# City not found. Skipping...
# Processing Record 65 of set 10 | Saldanha
# Processing Record 66 of set 10 | Lorengau
# Processing Record 67 of set 10 | Porosozero
# Processing Record 68 of set 10 | Gazli
# Processing Record 69 of set 10 | Zapolyarnyy
# Processing Record 70 of set 10 | Ambon
# Processing Record 71 of set 10 | Saint-Philippe
# Processing Record 72 of set 10 | Barrow
# Processing Record 73 of set 10 | Makakilo City
# Processing Record 74 of set 10 | Nishihara
# City not found. Skipping...
# Processing Record 75 of set 11 | Kamenka
# Processing Record 76 of set 11 | Kondinskoye
# Processing Record 77 of set 11 | Yar-Sale
# Processing Record 78 of set 11 | Winnemucca
# Processing Record 79 of set 11 | Dikson
# Processing Record 80 of set 11 | Sola
# Processing Record 81 of set 11 | Hilo
# Processing Record 82 of set 11 | Chuy
# Processing Record 83 of set 11 | Savannah Bight
# Processing Record 84 of set 11 | Ilulissat
# Processing Record 85 of set 11 | Bahir Dar
# Processing Record 86 of set 11 | Port Alfred
# Processing Record 87 of set 11 | Pevek
# Processing Record 88 of set 11 | Saint Anthony
# Processing Record 89 of set 11 | Salalah
# Processing Record 90 of set 11 | Butaritari
# Processing Record 91 of set 11 | Freudenstadt
# Processing Record 92 of set 11 | Tiksi
# Processing Record 93 of set 11 | Mitsamiouli
# Processing Record 94 of set 11 | Ribeira Grande
# Processing Record 95 of set 11 | Thompson
# Processing Record 96 of set 11 | Qasigiannguit
# City not found. Skipping...
# Processing Record 97 of set 12 | Santa Maria
# Processing Record 98 of set 12 | Hovd
# Processing Record 99 of set 12 | East London
# Processing Record 100 of set 12 | Nouadhibou
# Processing Record 101 of set 12 | Ituiutaba
# Processing Record 102 of set 12 | Ponta do Sol
# Processing Record 103 of set 12 | Durham
# Processing Record 104 of set 12 | Albany
# Processing Record 105 of set 12 | Jacareacanga
# Processing Record 106 of set 12 | Lompoc
# Processing Record 107 of set 12 | Tongzi
# Processing Record 108 of set 12 | Waddan
# Processing Record 109 of set 12 | Portage
# Processing Record 110 of set 12 | Juba
# Processing Record 111 of set 12 | Gat
# Processing Record 112 of set 12 | Nurota
# Processing Record 113 of set 12 | Tuktoyaktuk
# Processing Record 114 of set 12 | Yaan
# Processing Record 115 of set 12 | Ouallam
# Processing Record 116 of set 12 | Port-Cartier
# Processing Record 117 of set 12 | Lebu
# Processing Record 118 of set 12 | Durusu
# Processing Record 119 of set 12 | Olavarria
# Processing Record 120 of set 12 | Srednekolymsk
# Processing Record 121 of set 12 | Comodoro Rivadavia
# Processing Record 122 of set 12 | Pato Branco
# Processing Record 123 of set 12 | Huarmey
# Processing Record 124 of set 12 | Haileybury
# Processing Record 125 of set 12 | Bambous Virieux
# Processing Record 126 of set 12 | Kapaa
# Processing Record 127 of set 12 | Kununurra
# City not found. Skipping...
# Processing Record 128 of set 13 | Vryburg
# Processing Record 129 of set 13 | Taltal
# Processing Record 130 of set 13 | Thunder Bay
# Processing Record 131 of set 13 | Juegang
# Processing Record 132 of set 13 | Conde
# Processing Record 133 of set 13 | Vila Velha
# Processing Record 134 of set 13 | Gornopravdinsk
# Processing Record 135 of set 13 | Lubyany
# Processing Record 136 of set 13 | Anadyr
# Processing Record 137 of set 13 | Poum
# City not found. Skipping...
# Processing Record 138 of set 14 | Laguna
# Processing Record 139 of set 14 | Kaeo
# Processing Record 140 of set 14 | Villa de Reyes
# Processing Record 141 of set 14 | Ayni
# Processing Record 142 of set 14 | Vostok
# Processing Record 143 of set 14 | Tuatapere
# Processing Record 144 of set 14 | Ahipara
# Processing Record 145 of set 14 | Norman Wells
# Processing Record 146 of set 14 | Huanren
# Processing Record 147 of set 14 | Shimoda
# Processing Record 148 of set 14 | Dong Hoi
# Processing Record 149 of set 14 | Jamestown
# Processing Record 150 of set 14 | Acari
# Processing Record 151 of set 14 | Rio Grande
# Processing Record 152 of set 14 | Bubaque
# Processing Record 153 of set 14 | Audru
# Processing Record 154 of set 14 | Itapirapua
# Processing Record 155 of set 14 | Karratha
# Processing Record 156 of set 14 | Severo-Kurilsk
# Processing Record 157 of set 14 | Kinablangan
# Processing Record 158 of set 14 | Taoudenni
# Processing Record 159 of set 14 | Cabacao
# Processing Record 160 of set 14 | Mae Sot
# Processing Record 161 of set 14 | Magistralnyy
# Processing Record 162 of set 14 | Morondava
# Processing Record 163 of set 14 | Kijang
# Processing Record 164 of set 14 | Proletariy
# Processing Record 165 of set 14 | Arraial do Cabo
# Processing Record 166 of set 14 | Tecoanapa
# Processing Record 167 of set 14 | Guerrero Negro
# Processing Record 168 of set 14 | Sfantu Gheorghe
# Processing Record 169 of set 14 | Camocim
# Processing Record 170 of set 14 | Udachnyy
# Processing Record 171 of set 14 | Meulaboh
# Processing Record 172 of set 14 | Kalabagh
# Processing Record 173 of set 14 | Vera Cruz
# Processing Record 174 of set 14 | Voi
# Processing Record 175 of set 14 | Mahebourg
# Processing Record 176 of set 14 | Novoanninskiy
# Processing Record 177 of set 14 | Balkanabat
# Processing Record 178 of set 14 | Upernavik
# Processing Record 179 of set 14 | Te Anau
# Processing Record 180 of set 14 | Gamba
# Processing Record 181 of set 14 | Caranavi
# Processing Record 182 of set 14 | Bonthe
# Processing Record 183 of set 14 | Fuerte
# Processing Record 184 of set 14 | Marfino
# Processing Record 185 of set 14 | Beshpagir
# Processing Record 186 of set 14 | Kruisfontein
# Processing Record 187 of set 14 | Creston
# Processing Record 188 of set 14 | Port Hardy
# City not found. Skipping...
# Processing Record 189 of set 15 | Pinheiro Machado
# Processing Record 190 of set 15 | Srostki
# City not found. Skipping...
# Processing Record 191 of set 16 | Puerto Narino
# City not found. Skipping...
# Processing Record 192 of set 17 | Katsuura
# City not found. Skipping...
# Processing Record 193 of set 18 | Saint-Joseph
# Processing Record 194 of set 18 | Turukhansk
# Processing Record 195 of set 18 | Banos
# Processing Record 196 of set 18 | Puerto del Rosario
# City not found. Skipping...
# Processing Record 197 of set 19 | Isangel
# Processing Record 198 of set 19 | Saint George
# Processing Record 199 of set 19 | Henties Bay
# Processing Record 200 of set 19 | Bambanglipuro
# Processing Record 201 of set 19 | Puerto Ayora
# Processing Record 202 of set 19 | Meiganga
# Processing Record 203 of set 19 | Garmsar
# Processing Record 204 of set 19 | Yellowknife
# Processing Record 205 of set 19 | Arrifes
# Processing Record 206 of set 19 | Hofn
# Processing Record 207 of set 19 | Caborca
# Processing Record 208 of set 19 | Port Elizabeth
# Processing Record 209 of set 19 | Warman
# Processing Record 210 of set 19 | Montrose
# Processing Record 211 of set 19 | Mwingi
# Processing Record 212 of set 19 | Changji
# Processing Record 213 of set 19 | Luderitz
# Processing Record 214 of set 19 | Pochutla
# Processing Record 215 of set 19 | Oktyabrskoye
# Processing Record 216 of set 19 | Belaya Gora
# Processing Record 217 of set 19 | Mayo
# Processing Record 218 of set 19 | Falun
# Processing Record 219 of set 19 | Torbay
# Processing Record 220 of set 19 | Tucupita
# Processing Record 221 of set 19 | Hasaki
# Processing Record 222 of set 19 | Fortuna
# Processing Record 223 of set 19 | Collie
# Processing Record 224 of set 19 | Sitka
# Processing Record 225 of set 19 | Tommot
# Processing Record 226 of set 19 | Hobyo
# Processing Record 227 of set 19 | San Quintin
# Processing Record 228 of set 19 | Suntar
# Processing Record 229 of set 19 | Morgan City
# City not found. Skipping...
# Processing Record 230 of set 20 | Geraldton
# Processing Record 231 of set 20 | Bismarck
# Processing Record 232 of set 20 | Cabedelo
# City not found. Skipping...
# Processing Record 233 of set 21 | Ordu
# Processing Record 234 of set 21 | Acajutla
# City not found. Skipping...
# Processing Record 235 of set 22 | Timra
# Processing Record 236 of set 22 | Progreso
# Processing Record 237 of set 22 | Ambovombe
# Processing Record 238 of set 22 | Narsaq
# Processing Record 239 of set 22 | Forbes
# City not found. Skipping...
# Processing Record 240 of set 23 | Phultala
# Processing Record 241 of set 23 | Berlevag
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 242 of set 26 | Aksarka
# Processing Record 243 of set 26 | Itatskiy
# City not found. Skipping...
# Processing Record 244 of set 27 | Port Keats
# Processing Record 245 of set 27 | Santa Rosa
# Processing Record 246 of set 27 | Gummidipundi
# Processing Record 247 of set 27 | Tome
# Processing Record 248 of set 27 | Smithers
# Processing Record 249 of set 27 | Vestmannaeyjar
# City not found. Skipping...
# Processing Record 250 of set 28 | Makinsk
# Processing Record 251 of set 28 | Locri
# Processing Record 252 of set 28 | Aseri
# Processing Record 253 of set 28 | Atakpame
# Processing Record 254 of set 28 | Timbuktu
# Processing Record 255 of set 28 | Swellendam
# Processing Record 256 of set 28 | Koumac
# Processing Record 257 of set 28 | Staryy Nadym
# City not found. Skipping...
# Processing Record 258 of set 29 | Kabare
# City not found. Skipping...
# Processing Record 259 of set 30 | Agadez
# Processing Record 260 of set 30 | Alofi
# Processing Record 261 of set 30 | Amapa
# Processing Record 262 of set 30 | Lake Charles
# Processing Record 263 of set 30 | Fairbanks
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 264 of set 32 | Manavalakurichi
# Processing Record 265 of set 32 | Hazorasp
# City not found. Skipping...
# Processing Record 266 of set 33 | Bud
# Processing Record 267 of set 33 | Le Port
# Processing Record 268 of set 33 | Ekhabi
# Processing Record 269 of set 33 | Bhalki
# Processing Record 270 of set 33 | Yashkul
# Processing Record 271 of set 33 | Mount Gambier
# Processing Record 272 of set 33 | Dingle
# Processing Record 273 of set 33 | Corumba
# Processing Record 274 of set 33 | Motygino
# Processing Record 275 of set 33 | Port-Gentil
# Processing Record 276 of set 33 | Provideniya
# Processing Record 277 of set 33 | Cooma
# Processing Record 278 of set 33 | Huangmei
# Processing Record 279 of set 33 | Leningradskiy
# Processing Record 280 of set 33 | Pouembout
# Processing Record 281 of set 33 | Taywarah
# Processing Record 282 of set 33 | Mayumba
# Processing Record 283 of set 33 | Acapulco
# Processing Record 284 of set 33 | Pimenta Bueno
# Processing Record 285 of set 33 | Krasnovishersk
# Processing Record 286 of set 33 | Lexington
# Processing Record 287 of set 33 | Faanui
# City not found. Skipping...
# Processing Record 288 of set 34 | Litovko
# Processing Record 289 of set 34 | Aykhal
# City not found. Skipping...
# Processing Record 290 of set 35 | Ylojarvi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 291 of set 37 | Eyl
# Processing Record 292 of set 37 | Dunedin
# Processing Record 293 of set 37 | Mahon
# Processing Record 294 of set 37 | Margate
# Processing Record 295 of set 37 | Tsaratanana
# Processing Record 296 of set 37 | Yamada
# Processing Record 297 of set 37 | Codrington
# Processing Record 298 of set 37 | Kathu
# City not found. Skipping...
# Processing Record 299 of set 38 | Afogados da Ingazeira
# Processing Record 300 of set 38 | Suez
# Processing Record 301 of set 38 | Yinchuan
# Processing Record 302 of set 38 | Dwarka
# Processing Record 303 of set 38 | Targusor
# Processing Record 304 of set 38 | Alice Springs
# Processing Record 305 of set 38 | Arlit
# Processing Record 306 of set 38 | Yokadouma
# Processing Record 307 of set 38 | Navalmoral de la Mata
# Processing Record 308 of set 38 | Rani
# City not found. Skipping...
# Processing Record 309 of set 39 | Mount Isa
# Processing Record 310 of set 39 | Badarpur
# Processing Record 311 of set 39 | Mongu
# Processing Record 312 of set 39 | Waipawa
# City not found. Skipping...
# Processing Record 313 of set 40 | Nome
# Processing Record 314 of set 40 | Araouane
# Processing Record 315 of set 40 | Sale
# Processing Record 316 of set 40 | Matay
# Processing Record 317 of set 40 | Camara de Lobos
# Processing Record 318 of set 40 | Touros
# Processing Record 319 of set 40 | Viedma
# Processing Record 320 of set 40 | Bonavista
# Processing Record 321 of set 40 | Cascais
# Processing Record 322 of set 40 | Nisia Floresta
# City not found. Skipping...
# Processing Record 323 of set 41 | Cheremukhovo
# Processing Record 324 of set 41 | Flin Flon
# Processing Record 325 of set 41 | Dhandhuka
# Processing Record 326 of set 41 | Coloncito
# Processing Record 327 of set 41 | Hun
# Processing Record 328 of set 41 | Barber
# Processing Record 329 of set 41 | Constitucion
# City not found. Skipping...
# Processing Record 330 of set 42 | Dhidhdhoo
# Processing Record 331 of set 42 | Kedougou
# Processing Record 332 of set 42 | Talnakh
# Processing Record 333 of set 42 | Luena
# Processing Record 334 of set 42 | Rehoboth
# Processing Record 335 of set 42 | Alyangula
# Processing Record 336 of set 42 | Banda Aceh
# Processing Record 337 of set 42 | Tasiilaq
# Processing Record 338 of set 42 | Kahului
# Processing Record 339 of set 42 | Lasa
# Processing Record 340 of set 42 | Kavieng
# Processing Record 341 of set 42 | Caravelas
# Processing Record 342 of set 42 | Havre-Saint-Pierre
# Processing Record 343 of set 42 | Espanola
# Processing Record 344 of set 42 | Havoysund
# Processing Record 345 of set 42 | La Libertad
# Processing Record 346 of set 42 | Urman
# Processing Record 347 of set 42 | Conceicao do Araguaia
# Processing Record 348 of set 42 | Ibotirama
# Processing Record 349 of set 42 | Buritizeiro
# Processing Record 350 of set 42 | Kavaratti
# Processing Record 351 of set 42 | Saucillo
# Processing Record 352 of set 42 | Azul
# Processing Record 353 of set 42 | Nizhyn
# Processing Record 354 of set 42 | Chulman
# City not found. Skipping...
# Processing Record 355 of set 43 | Lagoa
# Processing Record 356 of set 43 | Altagracia de Orituco
# Processing Record 357 of set 43 | Liverpool
# Processing Record 358 of set 43 | Coquimbo
# Processing Record 359 of set 43 | Tocopilla
# Processing Record 360 of set 43 | Gweta
# Processing Record 361 of set 43 | Gewane
# Processing Record 362 of set 43 | Ust-Nera
# Processing Record 363 of set 43 | Hirara
# Processing Record 364 of set 43 | Bojnurd
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 365 of set 45 | Sibolga
# Processing Record 366 of set 45 | Cabo San Lucas
# Processing Record 367 of set 45 | Aklavik
# Processing Record 368 of set 45 | Cam Ranh
# Processing Record 369 of set 45 | Candolim
# Processing Record 370 of set 45 | Carutapera
# Processing Record 371 of set 45 | Luanda
# Processing Record 372 of set 45 | Faya
# Processing Record 373 of set 45 | Bonnyville
# Processing Record 374 of set 45 | Kieta
# Processing Record 375 of set 45 | Sapele
# Processing Record 376 of set 45 | Palana
# Processing Record 377 of set 45 | Sayyan
# Processing Record 378 of set 45 | Ndjole
# Processing Record 379 of set 45 | Kilrush
# Processing Record 380 of set 45 | Pitimbu
# Processing Record 381 of set 45 | Husavik
# Processing Record 382 of set 45 | Hambantota
# Processing Record 383 of set 45 | Saurimo
# Processing Record 384 of set 45 | Nyimba
# Processing Record 385 of set 45 | Salinopolis
# Processing Record 386 of set 45 | Kroya
# Processing Record 387 of set 45 | Kharp
# Processing Record 388 of set 45 | Lata
# Processing Record 389 of set 45 | Svetlaya
# Processing Record 390 of set 45 | Mitu
# Processing Record 391 of set 45 | Kudahuvadhoo
# Processing Record 392 of set 45 | Maua
# Processing Record 393 of set 45 | Imbituba
# Processing Record 394 of set 45 | Marrakesh
# City not found. Skipping...
# Processing Record 395 of set 46 | Awjilah
# Processing Record 396 of set 46 | Hervey Bay
# Processing Record 397 of set 46 | Qaqortoq
# Processing Record 398 of set 46 | Ostrovnoy
# Processing Record 399 of set 46 | Khuldabad
# Processing Record 400 of set 46 | Yekaterinovka
# City not found. Skipping...
# Processing Record 401 of set 47 | Chongwe
# Processing Record 402 of set 47 | Yulara
# Processing Record 403 of set 47 | Chimoio
# City not found. Skipping...
# Processing Record 404 of set 48 | Moche
# Processing Record 405 of set 48 | Samarinda
# Processing Record 406 of set 48 | Lulea
# Processing Record 407 of set 48 | Great Bend
# Processing Record 408 of set 48 | Vila do Maio
# Processing Record 409 of set 48 | Toora-Khem
# Processing Record 410 of set 48 | Batagay
# Processing Record 411 of set 48 | Pimentel
# Processing Record 412 of set 48 | Tautira
# Processing Record 413 of set 48 | Trelew
# Processing Record 414 of set 48 | Sibu
# Processing Record 415 of set 48 | Miyang
# Processing Record 416 of set 48 | Mathbaria
# Processing Record 417 of set 48 | Victoria
# Processing Record 418 of set 48 | Kitimat
# Processing Record 419 of set 48 | Padang
# Processing Record 420 of set 48 | Wajima
# Processing Record 421 of set 48 | Westport
# Processing Record 422 of set 48 | Fare
# Processing Record 423 of set 48 | Eldama Ravine
# Processing Record 424 of set 48 | Mantua
# Processing Record 425 of set 48 | Trinidad
# City not found. Skipping...
# Processing Record 426 of set 49 | Mapiri
# Processing Record 427 of set 49 | Puerto Varas
# Processing Record 428 of set 49 | Honiara
# Processing Record 429 of set 49 | Longyearbyen
# Processing Record 430 of set 49 | Akdepe
# Processing Record 431 of set 49 | Bosaso
# Processing Record 432 of set 49 | Hami
# Processing Record 433 of set 49 | Itoman
# Processing Record 434 of set 49 | Cururupu
# Processing Record 435 of set 49 | Vidim
# Processing Record 436 of set 49 | Saint-Pierre
# Processing Record 437 of set 49 | De Aar
# Processing Record 438 of set 49 | Nyeri
# Processing Record 439 of set 49 | Sovetskiy
# Processing Record 440 of set 49 | Cusco
# Processing Record 441 of set 49 | Praia da Vitoria
# Processing Record 442 of set 49 | Sena Madureira
# Processing Record 443 of set 49 | Marawi
# Processing Record 444 of set 49 | Sovetskoye
# Processing Record 445 of set 49 | Northam
# Processing Record 446 of set 49 | Nemuro
# Processing Record 447 of set 49 | Ballina
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 448 of set 51 | Pansemal
# City not found. Skipping...
# Processing Record 449 of set 52 | Belmonte
# Processing Record 450 of set 52 | Rincon
# Processing Record 451 of set 52 | Sao Joao da Barra
# Processing Record 452 of set 52 | Kontagora
# Processing Record 453 of set 52 | Bowen
# Processing Record 454 of set 52 | Daru
# Processing Record 455 of set 52 | Cherskiy
# Processing Record 456 of set 52 | Ostersund
# Processing Record 457 of set 52 | Bandarbeyla
# Processing Record 458 of set 52 | Ikwiriri
# Processing Record 459 of set 52 | Khuzdar
# City not found. Skipping...
# Processing Record 460 of set 53 | Elizabeth City
# Processing Record 461 of set 53 | Dalby
# Processing Record 462 of set 53 | Merauke
# Processing Record 463 of set 53 | Hay River
# City not found. Skipping...
# Processing Record 464 of set 54 | Olbia
# Processing Record 465 of set 54 | Buraydah
# Processing Record 466 of set 54 | Pokhara
# Processing Record 467 of set 54 | Ribeira Brava
# Processing Record 468 of set 54 | Rovaniemi
# Processing Record 469 of set 54 | Andros Town
# Processing Record 470 of set 54 | Shasta Lake
# Processing Record 471 of set 54 | Kaihua
# Processing Record 472 of set 54 | Rio Gallegos
# Processing Record 473 of set 54 | Gloversville
# Processing Record 474 of set 54 | Takaka
# Processing Record 475 of set 54 | Grand Junction
# Processing Record 476 of set 54 | Bulungu
# Processing Record 477 of set 54 | Sokolo
# Processing Record 478 of set 54 | Cockburn Town
# Processing Record 479 of set 54 | Morwa
# Processing Record 480 of set 54 | Portland
# Processing Record 481 of set 54 | Turan
# City not found. Skipping...
# Processing Record 482 of set 55 | Vardo
# Processing Record 483 of set 55 | Gobabis
# Processing Record 484 of set 55 | Camacha
# Processing Record 485 of set 55 | Zafra
# City not found. Skipping...
# Processing Record 486 of set 56 | Los Llanos de Aridane
# Processing Record 487 of set 56 | Wahiawa
# Processing Record 488 of set 56 | Umm Kaddadah
# Processing Record 489 of set 56 | Warrnambool
# Processing Record 490 of set 56 | Sterling
# Processing Record 491 of set 56 | Moshi
# Processing Record 492 of set 56 | Springbok
# Processing Record 493 of set 56 | Halifax
# Processing Record 494 of set 56 | Haputale
# City not found. Skipping...
# Processing Record 495 of set 57 | Tazmalt
# Processing Record 496 of set 57 | Skogn
# Processing Record 497 of set 57 | Iquitos
# Processing Record 498 of set 57 | Tateyama
# Processing Record 499 of set 57 | Salekhard
# Processing Record 500 of set 57 | Bathsheba
# Processing Record 501 of set 57 | High Level
# Processing Record 502 of set 57 | Wajid
# Processing Record 503 of set 57 | Airai
# Processing Record 504 of set 57 | Puerto Lumbreras
# Processing Record 505 of set 57 | Kulotino
# Processing Record 506 of set 57 | Jucuaran
# Processing Record 507 of set 57 | Inhambane
# Processing Record 508 of set 57 | Gallup
# Processing Record 509 of set 57 | Byumba
# Processing Record 510 of set 57 | Aras
# Processing Record 511 of set 57 | Kalmunai
# Processing Record 512 of set 57 | Sungaipenuh
# Processing Record 513 of set 57 | La Primavera
# City not found. Skipping...
# Processing Record 514 of set 58 | General Roca
# City not found. Skipping...
# Processing Record 515 of set 59 | Aldan
# Processing Record 516 of set 59 | Bartica
# Processing Record 517 of set 59 | Namtsy
# Processing Record 518 of set 59 | Namatanai
# Processing Record 519 of set 59 | Uige
# Processing Record 520 of set 59 | Otradnoye
# Processing Record 521 of set 59 | Klaksvik
# Processing Record 522 of set 59 | Kurumkan
# Processing Record 523 of set 59 | Rocha
# Processing Record 524 of set 59 | Ixtapa
# Processing Record 525 of set 59 | Thohoyandou
# Processing Record 526 of set 59 | Soyo
# City not found. Skipping...
# Processing Record 527 of set 60 | Ozinki
# Processing Record 528 of set 60 | Muros
# Processing Record 529 of set 60 | San Patricio
# Processing Record 530 of set 60 | Hammerfest
# Processing Record 531 of set 60 | Betare Oya
# Processing Record 532 of set 60 | Santa Cruz de la Palma
# Processing Record 533 of set 60 | Kirakira
# Processing Record 534 of set 60 | Ulaangom
# Processing Record 535 of set 60 | Atar
# Processing Record 536 of set 60 | Ambilobe
# Processing Record 537 of set 60 | Matehuala
# Processing Record 538 of set 60 | Islamkot
# Processing Record 539 of set 60 | Sinjar
# Processing Record 540 of set 60 | Beyneu
# Processing Record 541 of set 60 | Mehamn
# Processing Record 542 of set 60 | Dawlatabad
# City not found. Skipping...
# Processing Record 543 of set 61 | Saquarema
# Processing Record 544 of set 61 | Zhigansk
# Processing Record 545 of set 61 | Mandalgovi
# Processing Record 546 of set 61 | Clearlake
# Processing Record 547 of set 61 | Atikokan
# Processing Record 548 of set 61 | Dubna
# Processing Record 549 of set 61 | Gigmoto
# Processing Record 550 of set 61 | Vung Tau
# Processing Record 551 of set 61 | Seymchan
# Processing Record 552 of set 61 | Wanning
# Processing Record 553 of set 61 | Hualmay
# Processing Record 554 of set 61 | Linxia
# Processing Record 555 of set 61 | Pisco
# Processing Record 556 of set 61 | Opuwo
# City not found. Skipping...
# Processing Record 557 of set 62 | Fort Nelson
# Processing Record 558 of set 62 | Manzhouli
# Processing Record 559 of set 62 | Rudsar
# Processing Record 560 of set 62 | Samfya
# Processing Record 561 of set 62 | Juneau
# Processing Record 562 of set 62 | Broken Hill
# Processing Record 563 of set 62 | Aksu
# Processing Record 564 of set 62 | Ciudad Bolivar
# Processing Record 565 of set 62 | Sobolevo
# Processing Record 566 of set 62 | Nuuk
# Processing Record 567 of set 62 | Palmer
# Processing Record 568 of set 62 | Harper
# Processing Record 569 of set 62 | Jining
# Processing Record 570 of set 62 | Kichera
# Processing Record 571 of set 62 | Bembereke
# Processing Record 572 of set 62 | Amuntai
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated

weather_dict = {
             "City": city_name,
             "Cloudiness": cloudiness, 
             "Country": country,
             "Date": date, 
             "Humidity": humidity,
             "Lat": lat, 
             "Lng": lng, 
             "Max Temp": max_temp,
             "Wind Speed": wind_speed
                }

# Create a data frame from dictionary

weather_data = pd.DataFrame(weather_dict)

# Save data frame to CSV

weather_data.to_csv('weather_data.csv')

# Display data frame head 

weather_data.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Ushuaia          20      AR  1563128237        86 -54.81  -68.31
# 1         Carauari           2      BR  1563128299        70  -4.88  -66.90
# 2         Cidreira         100      BR  1563128299        74 -30.17  -50.22
# 3  Haines Junction          87      CA  1563128299        56  60.75 -137.51
# 4       Georgetown          40      GY  1563128142        74   6.80  -58.16
#
#    Max Temp  Wind Speed
# 0     41.00        2.66
# 1     85.47        2.53
# 2     58.11        6.89
# 3     55.95        6.42
# 4     87.80       16.11

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Built plot

plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=30, edgecolors="black")

# Add text to the plot

plt.ylim(20, 110)
plt.title('City Latitude vs. Max Temperature (08/22/2018)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Save the figure

plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Built plot

plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=30, edgecolors="black")

# Add text to the plot

plt.ylim(0, 105)
plt.title('City Latitude vs. Humidity (08/22/2018)')
plt.xlabel('Latitude')
plt.ylabel('Humudity (%)')
plt.grid(True)

# Save the figure

plt.savefig("Humidity_vs_Latitude.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Built plot

plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=30, edgecolors="black")

# Add text to the plot

plt.title('City Latitude vs. Cloudiness (08/22/2018)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure

plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Built plot

plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=30, edgecolors="black")

# Add text to the plot

plt.title('City Latitude vs. Humidity (08/22/2018)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Save the figure

plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot

plt.show()
